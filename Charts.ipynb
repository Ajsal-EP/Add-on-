# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajsal-EP/Add-on-/blob/main/Charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array(["A","B","C","D","E"])
y1 = np.array([2,5,9,6,3])
plt.bar(x1,y1,width=0.3,color = 'red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0,6])
y1 = np.array([0,10])
x2 = np.array([5,8])
y2 = np.array([2,50])

plt.subplot(2,1,1)
plt.plot(x1,y1)
plt.subplot(2,1,2)
plt.plot(x2,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,7,5,9,6,2])
y1 = np.array([5,9,2,4,3,11])

plt.plot(ypoints, color='red', marker='o')
plt.plot(y1, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=[15,5,35,25,20]
label=["Rashford","maguire","Bruno","Ronaldo","Sancho"]
plt.title=("UNITED")
plt.pie(x1,labels=label)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.random.normal(170,10,250)
plt.hist(x)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0,2])
y1 = np.array([3,7])
x2 = np.array([5,8])
y2 = np.array([2,50])
x3 = np.array([7,9])
y3 = np.array([6,20])
x4 = np.array([7,9])
y4 = np.array([6,20])
x5 = np.array([7,9])
y5 = np.array([6,20])
x6 = np.array([7,9])
y6 = np.array([6,20])

plt.subplot(2,3,1)
plt.plot(x1,y1)
plt.subplot(2,3,2)
plt.plot(x2,y2)
plt.subplot(2,3,3)
plt.plot(x3,y3)
plt.subplot(2,3,4)
plt.plot(x4,y4)
plt.subplot(2,3,5)
plt.plot(x5,y5)
plt.subplot(2,3,6)
plt.plot(x6,y6)

plt.show()
