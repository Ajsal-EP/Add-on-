# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajsal-EP/Add-on-/blob/main/pie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array(["A","B","C","D","E"])
y1 = np.array([2,5,9,6,3])
plt.bar(x1,y1,width=0.3,color = 'red')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0,6])
y1 = np.array([0,100])
x2 = np.array([5,8])
y2 = np.array([2,50])

plt.subplot(2,1,1)
plt.plot(x1,y1)
plt.subplot(2,1,2)
plt.plot(x2,y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([4,7,5,9,6,2])
y1 = np.array([5,9,2,4,3,11])

plt.plot(ypoints, color='red', marker='o')
plt.plot(y1, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1=[10,15,35,20,20]
label=["Rashford","pogba","bruno","Ronaldo","Sancho"]
plt.pie(x1,labels=label)
plt.show
# Out:
# <function matplotlib.pyplot.show>
